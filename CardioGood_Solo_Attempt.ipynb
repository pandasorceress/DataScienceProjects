# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/Python Course/CardioGoodFitness.csv")
# for Student Work on Case Study

# %%
#df.head()
#df.tail()
#df.shape
#df.describe()
#df.describe(include='all')
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
# What are the different types of data?
#the different data types are: object (3), int64 (6)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
# What is the distribution of different variables in the dataset?
sns.pairplot(df)
#Pair Plot displays distribution of each numerical variable but not categorical variable
#age is skewed to the right, education seems more normal but with high concentrations perhaps indicating multimodal
#usage also appears multimodal but with a slight right skew, fitness is almost evenly distributed,
#income is skewed to the right, miles  is also skewed to the right

# %%
sns.pairplot(df, corner=True)

# %%
#categorical variable distribution using bar graph
#sns.countplot(data=df, x='MaritalStatus', hue='Gender')
#sns.countplot(data=df, x='MaritalStatus')
sns.countplot(data=df, x='MaritalStatus', hue='Product')
#Shows distribution of married individuals divided into gender.
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
#sns.countplot(data=df, x='Gender')
sns.countplot(data=df, x='Gender', hue='Product')
#sns.countplot(data=df, x='Gender', hue='MaritalStatus')
#The most popular product among males is TM195
#The most popular product among females is TM195
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#sns.countplot(data=df, x='Product')
sns.countplot(data=df, x='Product', hue='MaritalStatus')
#Partnered people seem to prefer TM195
#Product purchased seems to be affected by marital status, but this can be combined with what we know of the preference for TM195 across gender to infer that marital status is less important in what is purchased.
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
#Is there significant correlation among some of the variables? YES
#significant corr between Miles and Fitness, Usage and Fitness, Income and Age, Usage and Miles, Education and Income
df[['Age', 'Fitness', 'Education', 'Miles', 'Usage', 'Income']].corr()
sns.heatmap(data=df[['Age', 'Fitness', 'Miles', 'Usage', 'Income']].corr(), annot=True);

# %%
#distribution of average number of miles for each product?
#sns.boxplot(data=df, x='Miles')
sns.histplot(data=df, x='Miles', hue='Product', kde=True,)
#g=sns.FacetGrid(df, col='Product')
#g.map(sns.histplot("Miles"));
#Using subplots may be too difficult for me currently..back to drawing board
# Out:
# <Axes: xlabel='Miles', ylabel='Count'>

# %%
#attempt 2 for dist of average miles for each product
#sns.stripplot(data=df, x='Product')
sns.jointplot(data=df, x='Product', y='Miles')

# %%
sns.boxplot(data=df, x='Miles')
sns.boxplot(data=df, x='Miles', hue='Product')
# Out:
# <Axes: xlabel='Miles'>

# %%
#sns.boxplot(data=df, x='Product', y='Miles', hue='Gender')
#sns.scatterplot(data=df, x='Product', y='Miles')
sns.violinplot(data=df, x='Product', y='Miles')
# Out:
# <Axes: xlabel='Product', ylabel='Miles'>

# %%
pd.pivot_table(df,'Miles', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
#it is nice to look at the data this way. Sometimes it is easier to understand in a different output.
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
df['Miles'].mean()
# Out:
# 103.19444444444444

# %%
sns.histplot(data=df, x='Product', y='Miles')
# Out:
# <Axes: xlabel='Product', ylabel='Miles'>

# %%
)
